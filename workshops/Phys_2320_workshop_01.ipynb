# %% [markdown]
# <a href="https://colab.research.google.com/github/jamunozlab/introductory_mechanics_spring_2026/blob/main/workshops/Phys_2320_workshop_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions
#
# This is workshop 1 of Phys 2320 Spring 2026 Semester at The University of Texas at El Paso with Munoz, the objective is to make sure that the technology is working for you.
#
# 1) After you click on 'Open in Colab', go to File->Save a Copy in Drive. It will be saved to your Google Drive.
#
# 2) Copy the code below and modify it so that it prints your name and that of your teammates.
#
# 3) Click on the big 'Share' icon in the upper right corner and make sure that you give access to 'Anyone with the link' in the ensuing pop-up
#
# 4) In that same pop-up, click on 'Copy link'
#
# 5) Paste the copied link on Blackboard as the answer to the question in Workshop 1.

# %%
#Team member number 1
first_name = "Jorge"
last_name = "Munoz"
print(first_name + " " + last_name + " loves physics")

# %%
#Team member number 2
first_name = "Marie"
last_name = "Curie"
print(first_name + " " + last_name + " loves physics")

# %%
#Team member number 3
first_name = "Albert"
last_name = "Einstein"
print(first_name + " " + last_name + " loves physics")

# %%
#Team member number 4
first_name = "Jocelyn"
last_name = "Bell"
print(first_name + " " + last_name + " loves physics")
